# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
#from IPython.core.interactiveshell import InteractiveShell

#InteractiveShell.ast_node_interactivity = "all"

sns.set(color_codes=True)
df = pd.read_csv(r'trial.csv')
df.head(5)
df = df.rename(columns={"physics": "phy", "chemistry": "chem",
",maths": "mathematics", "biology": "bio" })
df.head(5)
sns.boxplot(x=df['phy'])
plt.show()
sns.boxplot(x=df['chem'])
plt.show()
sns.boxplot(x=df['bio'])
# Out:
# <Axes: xlabel='bio'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['name'], df['phy'])
ax.set_xlabel('name')
ax.set_ylabel('phy')
plt.show()

# %%
data = np.random.randint(low=1,high=100,size=(10, 10))
  
# setting the parameter values
vmin = 30
vmax = 70
  
# plotting the heatmap
hm = sns.heatmap(data=data,vmin=vmin,vmax=vmax)

# %%
# displaying the plotted heatmap
plt.show()

plt.hist(df['phy'],bins = [25, 50, 75])
 
# Show plot
plt.show()
